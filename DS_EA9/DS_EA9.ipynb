# %%
#%pip install matplotlib

#%pip install scikit-learn
#%pip install catboost 


import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt

from catboost import CatBoostRegressor, Pool

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# ### EA 9 Classification Exercise (40 points + 3 points extra)
#
# There are 2 files training and test
#
# This dataset is designed to understand the factors that lead a person to leave their current job for HR research. By model(s) that uses the current credentials, demographics, and experience data you will predict the probability of a candidate looking for a new job or will work for the company, as well as interpreting affected factors on employee decision.

# %%
testURL= "https://raw.githubusercontent.com/WHPAN0108/BHT-DataScience-S23/main/classification/data/Assigment/aug_test.csv"
#"https://github.com/WHPAN0108/BHT-DataScience-S23/blob/main/classification/data/Assigment/aug_test.csv"

trainURL= "https://raw.githubusercontent.com/WHPAN0108/BHT-DataScience-S23/main/classification/data/Assigment/aug_train.csv"
#"https://github.com/WHPAN0108/BHT-DataScience-S23/blob/main/classification/data/Assigment/aug_train.csv"

# %% [markdown]
# Note:
# - The dataset is imbalanced.
# - Most features are categorical (Nominal, Ordinal, Binary), some with high cardinality.
# - Missing imputation can be a part of your pipeline as well.

# %% [markdown]
# #### Features:
#
# - **city_ development _index** : Developement index of the city (scaled)
# - **gender** : Gender of candidate
# - **relevent_experience** : Relevant experience of candidate
# - **enrolled_university** : Type of University course enrolled if any
# - **education_level** : Education level of candidate
# - **major_discipline** :Education major discipline of candidate
# - **experience** : Candidate total experience in years,
# - **company_type** : Type of current employer
# - **last_new_job** : Difference in years between previous job and current job
# - **training_hours** : training hours completed
# - **target** : 0 – Not looking for job change, 1 – Looking for a job change
#
# ### Task1 Data clean, imputation

# %%
trainData = pd.read_csv(trainURL, delimiter=',')
testData = pd.read_csv(testURL, delimiter=',')
trainData.describe(include='all')
# Out:
#         city_development_index gender      relevent_experience  \
# count              2100.000000   1585                     2100
# unique                     NaN      3                        2
# top                        NaN   Male  Has relevent experience
# freq                       NaN   1422                     1507
# mean                  0.826898    NaN                      NaN
# std                   0.124464    NaN                      NaN
# min                   0.448000    NaN                      NaN
# 25%                   0.729250    NaN                      NaN
# 50%                   0.899000    NaN                      NaN
# 75%                   0.920000    NaN                      NaN
# max                   0.949000    NaN                      NaN
#
#        enrolled_university education_level major_discipline experience  \
# count                 2051            2049             1768       2090
# unique                   3               5                6         22
# top          no_enrollment        Graduate             STEM        >20
# freq                  1484            1246             1556        369
# mean                   NaN             NaN              NaN        NaN
# std                    NaN             NaN              NaN        NaN
# min                    NaN             NaN              NaN        NaN
# 25%                    NaN             NaN              NaN        NaN
# 50%                    NaN             NaN              NaN        NaN
# 75%                    NaN             NaN              NaN        NaN
# max                    NaN             NaN              NaN        NaN
#
#        company_type last_new_job  training_hours       target
# count          1415         2048     2100.000000  2100.000000
# unique            6            6             NaN          NaN
# top         Pvt Ltd            1             NaN          NaN
# freq           1068          857             NaN          NaN
# mean            NaN          NaN       65.896190     0.254762
# std             NaN          NaN       58.432483     0.435831
# min             NaN          NaN        1.000000     0.000000
# 25%             NaN          NaN       24.000000     0.000000
# 50%             NaN          NaN       49.000000     0.000000
# 75%             NaN          NaN       89.250000     1.000000
# max             NaN          NaN      336.000000     1.000000

# %%
testData.describe(include='all')
# Out:
#         city_development_index gender      relevent_experience  \
# count               100.000000     72                      100
# unique                     NaN      3                        2
# top                        NaN   Male  Has relevent experience
# freq                       NaN     68                       66
# mean                  0.844220    NaN                      NaN
# std                   0.117719    NaN                      NaN
# min                   0.479000    NaN                      NaN
# 25%                   0.794750    NaN                      NaN
# 50%                   0.910000    NaN                      NaN
# 75%                   0.920000    NaN                      NaN
# max                   0.949000    NaN                      NaN
#
#        enrolled_university education_level major_discipline experience  \
# count                   96              98               88        100
# unique                   3               3                5         20
# top          no_enrollment        Graduate             STEM        >20
# freq                    67              63               82         17
# mean                   NaN             NaN              NaN        NaN
# std                    NaN             NaN              NaN        NaN
# min                    NaN             NaN              NaN        NaN
# 25%                    NaN             NaN              NaN        NaN
# 50%                    NaN             NaN              NaN        NaN
# 75%                    NaN             NaN              NaN        NaN
# max                    NaN             NaN              NaN        NaN
#
#        company_type last_new_job  training_hours      target
# count            64          100      100.000000  100.000000
# unique            5            6             NaN         NaN
# top         Pvt Ltd            1             NaN         NaN
# freq             50           40             NaN         NaN
# mean            NaN          NaN       72.280000    0.220000
# std             NaN          NaN       64.813498    0.416333
# min             NaN          NaN        4.000000    0.000000
# 25%             NaN          NaN       22.000000    0.000000
# 50%             NaN          NaN       51.500000    0.000000
# 75%             NaN          NaN       93.000000    0.000000
# max             NaN          NaN      310.000000    1.000000

# %% [markdown]
# 1. in experience, replace >20 to 21; <1 to 1, and convert this as a numerical column

# %%
trainData['experience'] = pd.to_numeric(trainData['experience'].replace({'>20': 21, '<1': 1}))
testData['experience'] = pd.to_numeric(testData['experience'].replace({'>20': 21, '<1': 1}))
testData.describe( include='all')
# Out:
#         city_development_index gender      relevent_experience  \
# count               100.000000     72                      100
# unique                     NaN      3                        2
# top                        NaN   Male  Has relevent experience
# freq                       NaN     68                       66
# mean                  0.844220    NaN                      NaN
# std                   0.117719    NaN                      NaN
# min                   0.479000    NaN                      NaN
# 25%                   0.794750    NaN                      NaN
# 50%                   0.910000    NaN                      NaN
# 75%                   0.920000    NaN                      NaN
# max                   0.949000    NaN                      NaN
#
#        enrolled_university education_level major_discipline  experience  \
# count                   96              98               88  100.000000
# unique                   3               3                5         NaN
# top          no_enrollment        Graduate             STEM         NaN
# freq                    67              63               82         NaN
# mean                   NaN             NaN              NaN   10.230000
# std                    NaN             NaN              NaN    6.637596
# min                    NaN             NaN              NaN    1.000000
# 25%                    NaN             NaN              NaN    4.000000
# 50%                    NaN             NaN              NaN    9.500000
# 75%                    NaN             NaN              NaN   15.000000
# max                    NaN             NaN              NaN   21.000000
#
#        company_type last_new_job  training_hours      target
# count            64          100      100.000000  100.000000
# unique            5            6             NaN         NaN
# top         Pvt Ltd            1             NaN         NaN
# freq             50           40             NaN         NaN
# mean            NaN          NaN       72.280000    0.220000
# std             NaN          NaN       64.813498    0.416333
# min             NaN          NaN        4.000000    0.000000
# 25%             NaN          NaN       22.000000    0.000000
# 50%             NaN          NaN       51.500000    0.000000
# 75%             NaN          NaN       93.000000    0.000000
# max             NaN          NaN      310.000000    1.000000

# %% [markdown]
# 2. in last_new_job, replace >4 to 5; never to 0, and convert this as a numerical column

# %%
trainData['last_new_job'] = pd.to_numeric(trainData['last_new_job'].replace({'>4': 5, 'never': 0}))
testData['last_new_job'] = pd.to_numeric(testData['last_new_job'].replace({'>4': 5, 'never': 0}))

# %% [markdown]
# 3. If the column is categorical, impute the missing value as its mode. If the column is numerical, impute the missing value as its median

# %%
def clean_columnData(df):   
    for column in df.select_dtypes(include=[np.number]).columns:
        median_value = df[column].median()
        replaced = df[column].fillna(median_value)
        df[column] = replaced

    for column in df.select_dtypes(exclude=[np.number]).columns:
        if (df[column].isnull().sum() > 0):
            replaced = df[column].fillna(df[column].mode()[0])
            df[column] = replaced

clean_columnData(trainData)
clean_columnData(testData)

# %% [markdown]
# ## Task2 Classification
#
# 1. Build a classification model from the training set ( you can use any algorithms)
# > CatBoost is an algorithm for gradient boosting on decision trees. It is developed by Yandex researchers and engineers, and is used for search, recommendation systems, personal assistant, self-driving cars, weather prediction and many other tasks at Yandex and in other companies, including CERN, Cloudflare, Careem taxi. It is in open-source and can be used by anyone. Reference : https://catboost.ai/

# %%
# we need to change the categorical data to numerical data so the model can understand it
trainDataDummies = pd.get_dummies(trainData)
testDataDummies = pd.get_dummies(testData)

# add missing columns to test data
missing_columns = set(trainDataDummies.columns) - set(testDataDummies.columns)
for column in missing_columns:
    testDataDummies[column] = False

# we now convert the binary columns into numerical ones.

# %%
def convert_bool_columns(df):
    for column in df.select_dtypes(include=['bool']).columns:
        df[column] = df[column].astype(int)

convert_bool_columns(trainDataDummies)
convert_bool_columns(testDataDummies)

testDataDummies = testDataDummies.reindex(columns=trainDataDummies.columns)

# %%
model = CatBoostRegressor(objective='RMSE')


Y_train = trainDataDummies['target']
# there are no identifying columns that could confuse the model, so we only remove target.
X_train = trainDataDummies.drop(columns=['target'])
model.fit(X_train, Y_train)
# Out:
# Learning rate set to 0.046035
# 0:	learn: 0.4325687	total: 1.42ms	remaining: 1.42s
# 1:	learn: 0.4297794	total: 2.63ms	remaining: 1.31s
# 2:	learn: 0.4268301	total: 3.9ms	remaining: 1.29s
# 3:	learn: 0.4242078	total: 5.5ms	remaining: 1.37s
# 4:	learn: 0.4217844	total: 7.07ms	remaining: 1.41s
# 5:	learn: 0.4196387	total: 8.34ms	remaining: 1.38s
# 6:	learn: 0.4175933	total: 9.63ms	remaining: 1.36s
# 7:	learn: 0.4157511	total: 10.8ms	remaining: 1.33s
# 8:	learn: 0.4143082	total: 11.9ms	remaining: 1.31s
# 9:	learn: 0.4124610	total: 13ms	remaining: 1.29s
# 10:	learn: 0.4107593	total: 14.3ms	remaining: 1.29s
# 11:	learn: 0.4093374	total: 15.5ms	remaining: 1.27s
# 12:	learn: 0.4081060	total: 16.7ms	remaining: 1.27s
# 13:	learn: 0.4068158	total: 18ms	remaining: 1.27s
# 14:	learn: 0.4057677	total: 19.1ms	remaining: 1.25s
# 15:	learn: 0.4046333	total: 20.3ms	remaining: 1.25s
# 16:	learn: 0.4036598	total: 21.4ms	remaining: 1.24s
# 17:	learn: 0.4026937	total: 22.5ms	remaining: 1.23s
# 18:	learn: 0.4019230	total: 23.2ms	remaining: 1.2s
# 19:	learn: 0.4010921	total: 24.4ms	remaining: 1.19s
# 20:	learn: 0.4001378	total: 25.4ms	remaining: 1.19s
# 21:	learn: 0.3993868	total: 26.6ms	remaining: 1.18s
# 22:	learn: 0.3985966	total: 27.9ms	remaining: 1.18s
# 23:	learn: 0.3978539	total: 29.2ms	remaining: 1.19s
# 24:	learn: 0.3973453	total: 30.7ms	remaining: 1.2s
# 25:	learn: 0.3967093	total: 31.9ms	remaining: 1.19s
# 26:	learn: 0.3961908	total: 33ms	remaining: 1.19s
# 27:	learn: 0.3954823	total: 34.2ms	remaining: 1.19s
# 28:	learn: 0.3950129	total: 35.3ms	remaining: 1.18s
# 29:	learn: 0.3943691	total: 36.6ms	remaining: 1.18s
# 30:	learn: 0.3938660	total: 38ms	remaining: 1.19s
# 31:	learn: 0.3935151	total: 39.3ms	remaining: 1.19s
# 32:	learn: 0.3930290	total: 40.5ms	remaining: 1.19s
# 33:	learn: 0.3926494	total: 41.6ms	remaining: 1.18s
# 34:	learn: 0.3922196	total: 42.9ms	remaining: 1.18s
# 35:	learn: 0.3917247	total: 44.1ms	remaining: 1.18s
# 36:	learn: 0.3911840	total: 45.4ms	remaining: 1.18s
# 37:	learn: 0.3908098	total: 46.7ms	remaining: 1.18s
# 38:	learn: 0.3903768	total: 47.9ms	remaining: 1.18s
# 39:	learn: 0.3900830	total: 49ms	remaining: 1.18s
# 40:	learn: 0.3897693	total: 50.6ms	remaining: 1.18s
# 41:	learn: 0.3892678	total: 52ms	remaining: 1.19s
# 42:	learn: 0.3889315	total: 53.2ms	remaining: 1.18s
# 43:	learn: 0.3885729	total: 54.4ms	remaining: 1.18s
# 44:	learn: 0.3881803	total: 55.6ms	remaining: 1.18s
# 45:	learn: 0.3878104	total: 57ms	remaining: 1.18s
# 46:	learn: 0.3873463	total: 58.4ms	remaining: 1.18s
# 47:	learn: 0.3872495	total: 59.4ms	remaining: 1.18s
# 48:	learn: 0.3869077	total: 60.5ms	remaining: 1.17s
# 49:	learn: 0.3866218	total: 61.9ms	remaining: 1.18s
# 50:	learn: 0.3864795	total: 63ms	remaining: 1.17s
# 51:	learn: 0.3861916	total: 64.1ms	remaining: 1.17s
# 52:	learn: 0.3857303	total: 65.7ms	remaining: 1.17s
# 53:	learn: 0.3854171	total: 67ms	remaining: 1.17s
# 54:	learn: 0.3852530	total: 68.1ms	remaining: 1.17s
# 55:	learn: 0.3849791	total: 69.2ms	remaining: 1.17s
# 56:	learn: 0.3847245	total: 70.4ms	remaining: 1.16s
# 57:	learn: 0.3844980	total: 71.5ms	remaining: 1.16s
# 58:	learn: 0.3843001	total: 72.7ms	remaining: 1.16s
# 59:	learn: 0.3840507	total: 73.8ms	remaining: 1.16s
# 60:	learn: 0.3838764	total: 75.1ms	remaining: 1.16s
# 61:	learn: 0.3836392	total: 76.3ms	remaining: 1.15s
# 62:	learn: 0.3834481	total: 77.9ms	remaining: 1.16s
# 63:	learn: 0.3833097	total: 79.4ms	remaining: 1.16s
# 64:	learn: 0.3831659	total: 80.6ms	remaining: 1.16s
# 65:	learn: 0.3829465	total: 81.8ms	remaining: 1.16s
# 66:	learn: 0.3826235	total: 83.1ms	remaining: 1.16s
# 67:	learn: 0.3825150	total: 84.4ms	remaining: 1.16s
# 68:	learn: 0.3822180	total: 85.8ms	remaining: 1.16s
# 69:	learn: 0.3818071	total: 87.2ms	remaining: 1.16s
# 70:	learn: 0.3815395	total: 88.4ms	remaining: 1.16s
# 71:	learn: 0.3813535	total: 89.6ms	remaining: 1.15s
# 72:	learn: 0.3810603	total: 90.6ms	remaining: 1.15s
# 73:	learn: 0.3810153	total: 91.3ms	remaining: 1.14s
# 74:	learn: 0.3807309	total: 92.6ms	remaining: 1.14s
# 75:	learn: 0.3805590	total: 94ms	remaining: 1.14s
# 76:	learn: 0.3803043	total: 95.2ms	remaining: 1.14s
# 77:	learn: 0.3800695	total: 96.4ms	remaining: 1.14s
# 78:	learn: 0.3798648	total: 97.7ms	remaining: 1.14s
# 79:	learn: 0.3797048	total: 99ms	remaining: 1.14s
# 80:	learn: 0.3793988	total: 100ms	remaining: 1.14s
# 81:	learn: 0.3793337	total: 101ms	remaining: 1.13s
# 82:	learn: 0.3792205	total: 102ms	remaining: 1.13s
# 83:	learn: 0.3790763	total: 104ms	remaining: 1.13s
# 84:	learn: 0.3788246	total: 105ms	remaining: 1.13s
# 85:	learn: 0.3785511	total: 106ms	remaining: 1.13s
# 86:	learn: 0.3783271	total: 107ms	remaining: 1.12s
# 87:	learn: 0.3780444	total: 108ms	remaining: 1.12s
# 88:	learn: 0.3778145	total: 110ms	remaining: 1.12s
# 89:	learn: 0.3776848	total: 111ms	remaining: 1.12s
# 90:	learn: 0.3774700	total: 112ms	remaining: 1.12s
# 91:	learn: 0.3773099	total: 113ms	remaining: 1.12s
# 92:	learn: 0.3771867	total: 114ms	remaining: 1.11s
# 93:	learn: 0.3770033	total: 115ms	remaining: 1.11s
# 94:	learn: 0.3768817	total: 116ms	remaining: 1.11s
# 95:	learn: 0.3768627	total: 117ms	remaining: 1.1s
# 96:	learn: 0.3766064	total: 118ms	remaining: 1.1s
# 97:	learn: 0.3764035	total: 119ms	remaining: 1.09s
# 98:	learn: 0.3760815	total: 120ms	remaining: 1.09s
# 99:	learn: 0.3758835	total: 121ms	remaining: 1.09s
# 100:	learn: 0.3757354	total: 122ms	remaining: 1.09s
# 101:	learn: 0.3754413	total: 123ms	remaining: 1.09s
# 102:	learn: 0.3752373	total: 125ms	remaining: 1.08s
# 103:	learn: 0.3750390	total: 126ms	remaining: 1.08s
# 104:	learn: 0.3749237	total: 127ms	remaining: 1.08s
# 105:	learn: 0.3748061	total: 128ms	remaining: 1.08s
# 106:	learn: 0.3747041	total: 129ms	remaining: 1.08s
# 107:	learn: 0.3745746	total: 131ms	remaining: 1.08s
# 108:	learn: 0.3742542	total: 132ms	remaining: 1.07s
# 109:	learn: 0.3740361	total: 133ms	remaining: 1.07s
# 110:	learn: 0.3738304	total: 134ms	remaining: 1.07s
# 111:	learn: 0.3737335	total: 135ms	remaining: 1.07s
# 112:	learn: 0.3736337	total: 136ms	remaining: 1.07s
# 113:	learn: 0.3734841	total: 137ms	remaining: 1.07s
# 114:	learn: 0.3733246	total: 138ms	remaining: 1.06s
# 115:	learn: 0.3730412	total: 139ms	remaining: 1.06s
# 116:	learn: 0.3728137	total: 141ms	remaining: 1.06s
# 117:	learn: 0.3726956	total: 142ms	remaining: 1.06s
# 118:	learn: 0.3725593	total: 143ms	remaining: 1.06s
# 119:	learn: 0.3723833	total: 144ms	remaining: 1.06s
# 120:	learn: 0.3721490	total: 146ms	remaining: 1.06s
# 121:	learn: 0.3719755	total: 147ms	remaining: 1.06s
# 122:	learn: 0.3718429	total: 148ms	remaining: 1.05s
# 123:	learn: 0.3718283	total: 148ms	remaining: 1.05s
# 124:	learn: 0.3716675	total: 149ms	remaining: 1.05s
# 125:	learn: 0.3715246	total: 151ms	remaining: 1.04s
# 126:	learn: 0.3714240	total: 152ms	remaining: 1.04s
# 127:	learn: 0.3711514	total: 153ms	remaining: 1.04s
# 128:	learn: 0.3708968	total: 154ms	remaining: 1.04s
# 129:	learn: 0.3708066	total: 155ms	remaining: 1.04s
# 130:	learn: 0.3705869	total: 156ms	remaining: 1.04s
# 131:	learn: 0.3704866	total: 158ms	remaining: 1.04s
# 132:	learn: 0.3703860	total: 159ms	remaining: 1.04s
# 133:	learn: 0.3702900	total: 160ms	remaining: 1.04s
# 134:	learn: 0.3701029	total: 162ms	remaining: 1.03s
# 135:	learn: 0.3698806	total: 163ms	remaining: 1.03s
# 136:	learn: 0.3696253	total: 164ms	remaining: 1.03s
# 137:	learn: 0.3694112	total: 165ms	remaining: 1.03s
# 138:	learn: 0.3692727	total: 166ms	remaining: 1.03s
# 139:	learn: 0.3690809	total: 167ms	remaining: 1.03s
# 140:	learn: 0.3687754	total: 168ms	remaining: 1.02s
# 141:	learn: 0.3685779	total: 169ms	remaining: 1.02s
# 142:	learn: 0.3683948	total: 171ms	remaining: 1.02s
# 143:	learn: 0.3682171	total: 172ms	remaining: 1.02s
# 144:	learn: 0.3680928	total: 173ms	remaining: 1.02s
# 145:	learn: 0.3678655	total: 175ms	remaining: 1.02s
# 146:	learn: 0.3678027	total: 176ms	remaining: 1.02s
# 147:	learn: 0.3676297	total: 177ms	remaining: 1.02s
# 148:	learn: 0.3673711	total: 178ms	remaining: 1.01s
# 149:	learn: 0.3671813	total: 179ms	remaining: 1.01s
# 150:	learn: 0.3671475	total: 180ms	remaining: 1.01s
# 151:	learn: 0.3669553	total: 181ms	remaining: 1.01s
# 152:	learn: 0.3667395	total: 182ms	remaining: 1.01s
# 153:	learn: 0.3665954	total: 183ms	remaining: 1.01s
# 154:	learn: 0.3664680	total: 184ms	remaining: 1s
# 155:	learn: 0.3663075	total: 186ms	remaining: 1s
# 156:	learn: 0.3661880	total: 187ms	remaining: 1s
# 157:	learn: 0.3659869	total: 188ms	remaining: 1s
# 158:	learn: 0.3657150	total: 190ms	remaining: 1s
# 159:	learn: 0.3656459	total: 191ms	remaining: 1s
# 160:	learn: 0.3655353	total: 192ms	remaining: 1000ms
# 161:	learn: 0.3652811	total: 193ms	remaining: 999ms
# 162:	learn: 0.3651450	total: 195ms	remaining: 1000ms
# 163:	learn: 0.3649002	total: 196ms	remaining: 999ms
# 164:	learn: 0.3646209	total: 197ms	remaining: 998ms
# 165:	learn: 0.3644879	total: 199ms	remaining: 998ms
# 166:	learn: 0.3643213	total: 200ms	remaining: 997ms
# 167:	learn: 0.3641803	total: 201ms	remaining: 996ms
# 168:	learn: 0.3639507	total: 203ms	remaining: 997ms
# 169:	learn: 0.3638394	total: 204ms	remaining: 996ms
# 170:	learn: 0.3636909	total: 205ms	remaining: 996ms
# 171:	learn: 0.3636383	total: 207ms	remaining: 995ms
# 172:	learn: 0.3635660	total: 208ms	remaining: 994ms
# 173:	learn: 0.3634873	total: 209ms	remaining: 993ms
# 174:	learn: 0.3634575	total: 211ms	remaining: 994ms
# 175:	learn: 0.3632821	total: 216ms	remaining: 1.01s
# 176:	learn: 0.3630242	total: 218ms	remaining: 1.01s
# 177:	learn: 0.3629024	total: 220ms	remaining: 1.02s
# 178:	learn: 0.3628039	total: 223ms	remaining: 1.02s
# 179:	learn: 0.3626336	total: 225ms	remaining: 1.02s
# 180:	learn: 0.3624154	total: 226ms	remaining: 1.02s
# 181:	learn: 0.3622504	total: 227ms	remaining: 1.02s
# 182:	learn: 0.3621115	total: 228ms	remaining: 1.02s
# 183:	learn: 0.3620056	total: 229ms	remaining: 1.02s
# 184:	learn: 0.3616569	total: 230ms	remaining: 1.01s
# 185:	learn: 0.3615274	total: 232ms	remaining: 1.01s
# 186:	learn: 0.3613530	total: 233ms	remaining: 1.01s
# 187:	learn: 0.3611444	total: 235ms	remaining: 1.01s
# 188:	learn: 0.3610377	total: 236ms	remaining: 1.01s
# 189:	learn: 0.3609111	total: 237ms	remaining: 1.01s
# 190:	learn: 0.3607458	total: 238ms	remaining: 1.01s
# 191:	learn: 0.3604654	total: 240ms	remaining: 1.01s
# 192:	learn: 0.3601890	total: 241ms	remaining: 1.01s
# 193:	learn: 0.3599562	total: 242ms	remaining: 1.01s
# 194:	learn: 0.3598637	total: 244ms	remaining: 1s
# 195:	learn: 0.3596604	total: 245ms	remaining: 1s
# 196:	learn: 0.3595351	total: 246ms	remaining: 1s
# 197:	learn: 0.3594332	total: 247ms	remaining: 1s
# 198:	learn: 0.3593809	total: 248ms	remaining: 999ms
# 199:	learn: 0.3591922	total: 249ms	remaining: 998ms
# 200:	learn: 0.3591038	total: 251ms	remaining: 997ms
# 201:	learn: 0.3589877	total: 252ms	remaining: 995ms
# 202:	learn: 0.3588873	total: 253ms	remaining: 994ms
# 203:	learn: 0.3588084	total: 254ms	remaining: 992ms
# 204:	learn: 0.3587399	total: 255ms	remaining: 991ms
# 205:	learn: 0.3586631	total: 257ms	remaining: 989ms
# 206:	learn: 0.3586079	total: 258ms	remaining: 987ms
# 207:	learn: 0.3584309	total: 259ms	remaining: 985ms
# 208:	learn: 0.3582988	total: 260ms	remaining: 983ms
# 209:	learn: 0.3581858	total: 261ms	remaining: 981ms
# 210:	learn: 0.3579867	total: 262ms	remaining: 980ms
# 211:	learn: 0.3577345	total: 263ms	remaining: 978ms
# 212:	learn: 0.3576898	total: 264ms	remaining: 977ms
# 213:	learn: 0.3576172	total: 266ms	remaining: 976ms
# 214:	learn: 0.3575960	total: 267ms	remaining: 976ms
# 215:	learn: 0.3575219	total: 268ms	remaining: 974ms
# 216:	learn: 0.3573552	total: 270ms	remaining: 972ms
# 217:	learn: 0.3573225	total: 271ms	remaining: 971ms
# 218:	learn: 0.3570318	total: 272ms	remaining: 970ms
# 219:	learn: 0.3569359	total: 273ms	remaining: 968ms
# 220:	learn: 0.3568248	total: 274ms	remaining: 967ms
# 221:	learn: 0.3565650	total: 275ms	remaining: 965ms
# 222:	learn: 0.3564436	total: 276ms	remaining: 963ms
# 223:	learn: 0.3563432	total: 278ms	remaining: 962ms
# 224:	learn: 0.3560880	total: 279ms	remaining: 960ms
# 225:	learn: 0.3559996	total: 280ms	remaining: 958ms
# 226:	learn: 0.3558511	total: 281ms	remaining: 957ms
# 227:	learn: 0.3556913	total: 282ms	remaining: 955ms
# 228:	learn: 0.3555752	total: 283ms	remaining: 953ms
# 229:	learn: 0.3554098	total: 284ms	remaining: 952ms
# 230:	learn: 0.3551993	total: 285ms	remaining: 950ms
# 231:	learn: 0.3550589	total: 286ms	remaining: 948ms
# 232:	learn: 0.3550370	total: 287ms	remaining: 946ms
# 233:	learn: 0.3548720	total: 289ms	remaining: 944ms
# 234:	learn: 0.3547568	total: 290ms	remaining: 943ms
# 235:	learn: 0.3544616	total: 291ms	remaining: 942ms
# 236:	learn: 0.3543716	total: 292ms	remaining: 940ms
# 237:	learn: 0.3542807	total: 293ms	remaining: 938ms
# 238:	learn: 0.3541852	total: 294ms	remaining: 936ms
# 239:	learn: 0.3541639	total: 295ms	remaining: 935ms
# 240:	learn: 0.3539567	total: 296ms	remaining: 933ms
# 241:	learn: 0.3537724	total: 297ms	remaining: 932ms
# 242:	learn: 0.3536368	total: 299ms	remaining: 931ms
# 243:	learn: 0.3533829	total: 300ms	remaining: 930ms
# 244:	learn: 0.3532174	total: 301ms	remaining: 929ms
# 245:	learn: 0.3530610	total: 302ms	remaining: 927ms
# 246:	learn: 0.3528810	total: 304ms	remaining: 925ms
# 247:	learn: 0.3526779	total: 305ms	remaining: 924ms
# 248:	learn: 0.3525216	total: 306ms	remaining: 922ms
# 249:	learn: 0.3524234	total: 307ms	remaining: 920ms
# 250:	learn: 0.3523052	total: 308ms	remaining: 919ms
# 251:	learn: 0.3521118	total: 309ms	remaining: 918ms
# 252:	learn: 0.3520349	total: 310ms	remaining: 916ms
# 253:	learn: 0.3519545	total: 312ms	remaining: 915ms
# 254:	learn: 0.3517267	total: 313ms	remaining: 914ms
# 255:	learn: 0.3515451	total: 314ms	remaining: 913ms
# 256:	learn: 0.3513190	total: 315ms	remaining: 911ms
# 257:	learn: 0.3510822	total: 316ms	remaining: 910ms
# 258:	learn: 0.3509173	total: 318ms	remaining: 909ms
# 259:	learn: 0.3506228	total: 319ms	remaining: 907ms
# 260:	learn: 0.3506080	total: 320ms	remaining: 905ms
# 261:	learn: 0.3504767	total: 321ms	remaining: 903ms
# 262:	learn: 0.3503315	total: 322ms	remaining: 902ms
# 263:	learn: 0.3502323	total: 323ms	remaining: 900ms
# 264:	learn: 0.3500507	total: 324ms	remaining: 900ms
# 265:	learn: 0.3498396	total: 326ms	remaining: 899ms
# 266:	learn: 0.3497432	total: 327ms	remaining: 899ms
# 267:	learn: 0.3495388	total: 329ms	remaining: 898ms
# 268:	learn: 0.3493589	total: 330ms	remaining: 896ms
# 269:	learn: 0.3491226	total: 331ms	remaining: 895ms
# 270:	learn: 0.3491090	total: 332ms	remaining: 893ms
# 271:	learn: 0.3489716	total: 333ms	remaining: 891ms
# 272:	learn: 0.3487427	total: 334ms	remaining: 890ms
# 273:	learn: 0.3486665	total: 335ms	remaining: 888ms
# 274:	learn: 0.3485356	total: 336ms	remaining: 887ms
# 275:	learn: 0.3484761	total: 337ms	remaining: 885ms
# 276:	learn: 0.3483154	total: 339ms	remaining: 884ms
# 277:	learn: 0.3482990	total: 340ms	remaining: 882ms
# 278:	learn: 0.3480894	total: 341ms	remaining: 881ms
# 279:	learn: 0.3478494	total: 342ms	remaining: 879ms
# 280:	learn: 0.3476637	total: 343ms	remaining: 878ms
# 281:	learn: 0.3476515	total: 344ms	remaining: 877ms
# 282:	learn: 0.3475250	total: 346ms	remaining: 876ms
# 283:	learn: 0.3473841	total: 347ms	remaining: 874ms
# 284:	learn: 0.3472376	total: 348ms	remaining: 873ms
# 285:	learn: 0.3470802	total: 349ms	remaining: 871ms
# 286:	learn: 0.3469595	total: 350ms	remaining: 870ms
# 287:	learn: 0.3467741	total: 351ms	remaining: 868ms
# 288:	learn: 0.3466597	total: 352ms	remaining: 867ms
# 289:	learn: 0.3464865	total: 353ms	remaining: 865ms
# 290:	learn: 0.3463929	total: 355ms	remaining: 864ms
# 291:	learn: 0.3463284	total: 356ms	remaining: 863ms
# 292:	learn: 0.3461909	total: 357ms	remaining: 861ms
# 293:	learn: 0.3459264	total: 358ms	remaining: 860ms
# 294:	learn: 0.3458429	total: 359ms	remaining: 858ms
# 295:	learn: 0.3457580	total: 360ms	remaining: 857ms
# 296:	learn: 0.3456763	total: 362ms	remaining: 856ms
# 297:	learn: 0.3455916	total: 363ms	remaining: 854ms
# 298:	learn: 0.3455263	total: 364ms	remaining: 853ms
# 299:	learn: 0.3454016	total: 365ms	remaining: 851ms
# 300:	learn: 0.3451831	total: 366ms	remaining: 850ms
# 301:	learn: 0.3450631	total: 367ms	remaining: 848ms
# 302:	learn: 0.3449388	total: 368ms	remaining: 847ms
# 303:	learn: 0.3447625	total: 369ms	remaining: 846ms
# 304:	learn: 0.3445299	total: 370ms	remaining: 844ms
# 305:	learn: 0.3443444	total: 371ms	remaining: 842ms
# 306:	learn: 0.3441866	total: 373ms	remaining: 841ms
# 307:	learn: 0.3439383	total: 374ms	remaining: 840ms
# 308:	learn: 0.3437656	total: 375ms	remaining: 839ms
# 309:	learn: 0.3436698	total: 377ms	remaining: 838ms
# 310:	learn: 0.3434662	total: 378ms	remaining: 837ms
# 311:	learn: 0.3434597	total: 379ms	remaining: 835ms
# 312:	learn: 0.3433311	total: 380ms	remaining: 834ms
# 313:	learn: 0.3432062	total: 381ms	remaining: 832ms
# 314:	learn: 0.3430990	total: 383ms	remaining: 833ms
# 315:	learn: 0.3428784	total: 384ms	remaining: 831ms
# 316:	learn: 0.3427295	total: 385ms	remaining: 830ms
# 317:	learn: 0.3426404	total: 386ms	remaining: 828ms
# 318:	learn: 0.3424735	total: 387ms	remaining: 827ms
# 319:	learn: 0.3424155	total: 389ms	remaining: 826ms
# 320:	learn: 0.3422164	total: 390ms	remaining: 825ms
# 321:	learn: 0.3419236	total: 391ms	remaining: 823ms
# 322:	learn: 0.3417200	total: 392ms	remaining: 822ms
# 323:	learn: 0.3417036	total: 393ms	remaining: 820ms
# 324:	learn: 0.3415990	total: 394ms	remaining: 819ms
# 325:	learn: 0.3414886	total: 395ms	remaining: 817ms
# 326:	learn: 0.3413609	total: 397ms	remaining: 816ms
# 327:	learn: 0.3412715	total: 398ms	remaining: 816ms
# 328:	learn: 0.3411493	total: 399ms	remaining: 815ms
# 329:	learn: 0.3409716	total: 401ms	remaining: 814ms
# 330:	learn: 0.3409617	total: 402ms	remaining: 812ms
# 331:	learn: 0.3408147	total: 403ms	remaining: 811ms
# 332:	learn: 0.3406064	total: 405ms	remaining: 811ms
# 333:	learn: 0.3405073	total: 406ms	remaining: 810ms
# 334:	learn: 0.3403869	total: 407ms	remaining: 808ms
# 335:	learn: 0.3403780	total: 408ms	remaining: 807ms
# 336:	learn: 0.3402656	total: 409ms	remaining: 806ms
# 337:	learn: 0.3402563	total: 411ms	remaining: 804ms
# 338:	learn: 0.3402215	total: 412ms	remaining: 803ms
# 339:	learn: 0.3400451	total: 413ms	remaining: 802ms
# 340:	learn: 0.3399093	total: 414ms	remaining: 800ms
# 341:	learn: 0.3397914	total: 415ms	remaining: 799ms
# 342:	learn: 0.3396672	total: 416ms	remaining: 797ms
# 343:	learn: 0.3394335	total: 417ms	remaining: 796ms
# 344:	learn: 0.3393325	total: 418ms	remaining: 794ms
# 345:	learn: 0.3392190	total: 420ms	remaining: 794ms
# 346:	learn: 0.3389698	total: 421ms	remaining: 793ms
# 347:	learn: 0.3388085	total: 422ms	remaining: 791ms
# 348:	learn: 0.3386364	total: 423ms	remaining: 790ms
# 349:	learn: 0.3384695	total: 425ms	remaining: 788ms
# 350:	learn: 0.3383841	total: 426ms	remaining: 787ms
# 351:	learn: 0.3382221	total: 427ms	remaining: 786ms
# 352:	learn: 0.3380937	total: 428ms	remaining: 784ms
# 353:	learn: 0.3379825	total: 429ms	remaining: 783ms
# 354:	learn: 0.3379098	total: 430ms	remaining: 782ms
# 355:	learn: 0.3378390	total: 431ms	remaining: 780ms
# 356:	learn: 0.3378273	total: 432ms	remaining: 778ms
# 357:	learn: 0.3376312	total: 433ms	remaining: 777ms
# 358:	learn: 0.3374429	total: 435ms	remaining: 776ms
# 359:	learn: 0.3373434	total: 436ms	remaining: 775ms
# 360:	learn: 0.3372266	total: 437ms	remaining: 774ms
# 361:	learn: 0.3370600	total: 438ms	remaining: 773ms
# 362:	learn: 0.3369619	total: 440ms	remaining: 772ms
# 363:	learn: 0.3367236	total: 441ms	remaining: 770ms
# 364:	learn: 0.3366032	total: 442ms	remaining: 769ms
# 365:	learn: 0.3365822	total: 443ms	remaining: 767ms
# 366:	learn: 0.3364254	total: 444ms	remaining: 766ms
# 367:	learn: 0.3362340	total: 445ms	remaining: 765ms
# 368:	learn: 0.3362259	total: 446ms	remaining: 763ms
# 369:	learn: 0.3360120	total: 448ms	remaining: 762ms
# 370:	learn: 0.3358201	total: 449ms	remaining: 761ms
# 371:	learn: 0.3357031	total: 450ms	remaining: 760ms
# 372:	learn: 0.3356310	total: 451ms	remaining: 758ms
# 373:	learn: 0.3355407	total: 452ms	remaining: 757ms
# 374:	learn: 0.3354313	total: 453ms	remaining: 755ms
# 375:	learn: 0.3353593	total: 454ms	remaining: 754ms
# 376:	learn: 0.3353052	total: 455ms	remaining: 753ms
# 377:	learn: 0.3351592	total: 457ms	remaining: 751ms
# 378:	learn: 0.3350657	total: 458ms	remaining: 750ms
# 379:	learn: 0.3349474	total: 469ms	remaining: 765ms
# 380:	learn: 0.3347641	total: 470ms	remaining: 764ms
# 381:	learn: 0.3344917	total: 471ms	remaining: 763ms
# 382:	learn: 0.3344056	total: 473ms	remaining: 761ms
# 383:	learn: 0.3343367	total: 474ms	remaining: 760ms
# 384:	learn: 0.3342616	total: 475ms	remaining: 758ms
# 385:	learn: 0.3340915	total: 476ms	remaining: 757ms
# 386:	learn: 0.3339216	total: 477ms	remaining: 756ms
# 387:	learn: 0.3336837	total: 478ms	remaining: 754ms
# 388:	learn: 0.3335965	total: 479ms	remaining: 752ms
# 389:	learn: 0.3334372	total: 480ms	remaining: 751ms
# 390:	learn: 0.3333460	total: 481ms	remaining: 750ms
# 391:	learn: 0.3332266	total: 483ms	remaining: 749ms
# 392:	learn: 0.3330780	total: 484ms	remaining: 747ms
# 393:	learn: 0.3330238	total: 485ms	remaining: 746ms
# 394:	learn: 0.3328395	total: 486ms	remaining: 745ms
# 395:	learn: 0.3325880	total: 487ms	remaining: 743ms
# 396:	learn: 0.3324410	total: 488ms	remaining: 742ms
# 397:	learn: 0.3322973	total: 490ms	remaining: 741ms
# 398:	learn: 0.3322000	total: 491ms	remaining: 739ms
# 399:	learn: 0.3319723	total: 492ms	remaining: 738ms
# 400:	learn: 0.3318995	total: 493ms	remaining: 736ms
# 401:	learn: 0.3317290	total: 494ms	remaining: 735ms
# 402:	learn: 0.3315951	total: 495ms	remaining: 734ms
# 403:	learn: 0.3314387	total: 497ms	remaining: 733ms
# 404:	learn: 0.3312838	total: 498ms	remaining: 731ms
# 405:	learn: 0.3312262	total: 499ms	remaining: 730ms
# 406:	learn: 0.3311866	total: 500ms	remaining: 728ms
# 407:	learn: 0.3310186	total: 501ms	remaining: 727ms
# 408:	learn: 0.3308773	total: 502ms	remaining: 726ms
# 409:	learn: 0.3306697	total: 504ms	remaining: 725ms
# 410:	learn: 0.3305999	total: 505ms	remaining: 723ms
# 411:	learn: 0.3303956	total: 506ms	remaining: 722ms
# 412:	learn: 0.3302696	total: 507ms	remaining: 721ms
# 413:	learn: 0.3301568	total: 508ms	remaining: 719ms
# 414:	learn: 0.3299876	total: 509ms	remaining: 718ms
# 415:	learn: 0.3298428	total: 511ms	remaining: 717ms
# 416:	learn: 0.3296995	total: 512ms	remaining: 716ms
# 417:	learn: 0.3295295	total: 513ms	remaining: 714ms
# 418:	learn: 0.3294082	total: 515ms	remaining: 714ms
# 419:	learn: 0.3292298	total: 516ms	remaining: 712ms
# 420:	learn: 0.3291476	total: 517ms	remaining: 711ms
# 421:	learn: 0.3290220	total: 518ms	remaining: 710ms
# 422:	learn: 0.3288342	total: 519ms	remaining: 708ms
# 423:	learn: 0.3287209	total: 520ms	remaining: 707ms
# 424:	learn: 0.3286610	total: 522ms	remaining: 706ms
# 425:	learn: 0.3284927	total: 523ms	remaining: 704ms
# 426:	learn: 0.3283757	total: 524ms	remaining: 703ms
# 427:	learn: 0.3283421	total: 525ms	remaining: 701ms
# 428:	learn: 0.3282473	total: 526ms	remaining: 700ms
# 429:	learn: 0.3281801	total: 527ms	remaining: 699ms
# 430:	learn: 0.3280925	total: 528ms	remaining: 697ms
# 431:	learn: 0.3280247	total: 530ms	remaining: 696ms
# 432:	learn: 0.3279849	total: 531ms	remaining: 695ms
# 433:	learn: 0.3278274	total: 532ms	remaining: 694ms
# 434:	learn: 0.3277162	total: 533ms	remaining: 692ms
# 435:	learn: 0.3276500	total: 534ms	remaining: 691ms
# 436:	learn: 0.3274958	total: 535ms	remaining: 690ms
# 437:	learn: 0.3273953	total: 536ms	remaining: 688ms
# 438:	learn: 0.3273607	total: 538ms	remaining: 687ms
# 439:	learn: 0.3272234	total: 539ms	remaining: 686ms
# 440:	learn: 0.3270670	total: 540ms	remaining: 684ms
# 441:	learn: 0.3270034	total: 541ms	remaining: 683ms
# 442:	learn: 0.3268874	total: 542ms	remaining: 682ms
# 443:	learn: 0.3267588	total: 543ms	remaining: 680ms
# 444:	learn: 0.3267232	total: 544ms	remaining: 679ms
# 445:	learn: 0.3266834	total: 546ms	remaining: 678ms
# 446:	learn: 0.3265099	total: 547ms	remaining: 677ms
# 447:	learn: 0.3263798	total: 548ms	remaining: 675ms
# 448:	learn: 0.3262707	total: 549ms	remaining: 674ms
# 449:	learn: 0.3262037	total: 550ms	remaining: 673ms
# 450:	learn: 0.3261697	total: 551ms	remaining: 671ms
# 451:	learn: 0.3259086	total: 552ms	remaining: 670ms
# 452:	learn: 0.3257637	total: 553ms	remaining: 668ms
# 453:	learn: 0.3256114	total: 555ms	remaining: 667ms
# 454:	learn: 0.3255275	total: 556ms	remaining: 666ms
# 455:	learn: 0.3252675	total: 557ms	remaining: 664ms
# 456:	learn: 0.3251190	total: 558ms	remaining: 663ms
# 457:	learn: 0.3250743	total: 559ms	remaining: 662ms
# 458:	learn: 0.3249457	total: 560ms	remaining: 661ms
# 459:	learn: 0.3248082	total: 562ms	remaining: 659ms
# 460:	learn: 0.3247687	total: 563ms	remaining: 658ms
# 461:	learn: 0.3246699	total: 564ms	remaining: 657ms
# 462:	learn: 0.3244491	total: 565ms	remaining: 655ms
# 463:	learn: 0.3242929	total: 566ms	remaining: 654ms
# 464:	learn: 0.3241106	total: 567ms	remaining: 653ms
# 465:	learn: 0.3240951	total: 568ms	remaining: 651ms
# 466:	learn: 0.3240055	total: 570ms	remaining: 650ms
# 467:	learn: 0.3238412	total: 571ms	remaining: 649ms
# 468:	learn: 0.3236700	total: 572ms	remaining: 648ms
# 469:	learn: 0.3234175	total: 573ms	remaining: 646ms
# 470:	learn: 0.3232162	total: 574ms	remaining: 645ms
# 471:	learn: 0.3232099	total: 575ms	remaining: 644ms
# 472:	learn: 0.3231118	total: 576ms	remaining: 642ms
# 473:	learn: 0.3230642	total: 578ms	remaining: 641ms
# 474:	learn: 0.3229321	total: 579ms	remaining: 640ms
# 475:	learn: 0.3228905	total: 580ms	remaining: 638ms
# 476:	learn: 0.3227871	total: 581ms	remaining: 637ms
# 477:	learn: 0.3225067	total: 582ms	remaining: 636ms
# 478:	learn: 0.3224558	total: 584ms	remaining: 635ms
# 479:	learn: 0.3223621	total: 585ms	remaining: 634ms
# 480:	learn: 0.3222601	total: 586ms	remaining: 632ms
# 481:	learn: 0.3221474	total: 587ms	remaining: 631ms
# 482:	learn: 0.3220667	total: 588ms	remaining: 630ms
# 483:	learn: 0.3219395	total: 589ms	remaining: 628ms
# 484:	learn: 0.3218587	total: 591ms	remaining: 627ms
# 485:	learn: 0.3217961	total: 592ms	remaining: 626ms
# 486:	learn: 0.3217208	total: 593ms	remaining: 624ms
# 487:	learn: 0.3215591	total: 594ms	remaining: 623ms
# 488:	learn: 0.3215081	total: 595ms	remaining: 622ms
# 489:	learn: 0.3213972	total: 596ms	remaining: 620ms
# 490:	learn: 0.3212360	total: 598ms	remaining: 620ms
# 491:	learn: 0.3211276	total: 599ms	remaining: 618ms
# 492:	learn: 0.3210684	total: 600ms	remaining: 617ms
# 493:	learn: 0.3210334	total: 602ms	remaining: 616ms
# 494:	learn: 0.3208780	total: 603ms	remaining: 615ms
# 495:	learn: 0.3207723	total: 604ms	remaining: 614ms
# 496:	learn: 0.3207085	total: 605ms	remaining: 612ms
# 497:	learn: 0.3206829	total: 606ms	remaining: 611ms
# 498:	learn: 0.3206585	total: 607ms	remaining: 610ms
# 499:	learn: 0.3206115	total: 609ms	remaining: 609ms
# 500:	learn: 0.3203672	total: 610ms	remaining: 608ms
# 501:	learn: 0.3201717	total: 611ms	remaining: 606ms
# 502:	learn: 0.3200384	total: 612ms	remaining: 605ms
# 503:	learn: 0.3198788	total: 614ms	remaining: 604ms
# 504:	learn: 0.3197431	total: 615ms	remaining: 603ms
# 505:	learn: 0.3196900	total: 616ms	remaining: 601ms
# 506:	learn: 0.3194552	total: 617ms	remaining: 600ms
# 507:	learn: 0.3193355	total: 618ms	remaining: 599ms
# 508:	learn: 0.3191586	total: 619ms	remaining: 597ms
# 509:	learn: 0.3190409	total: 620ms	remaining: 596ms
# 510:	learn: 0.3189362	total: 622ms	remaining: 595ms
# 511:	learn: 0.3187647	total: 623ms	remaining: 594ms
# 512:	learn: 0.3186780	total: 624ms	remaining: 593ms
# 513:	learn: 0.3186029	total: 626ms	remaining: 591ms
# 514:	learn: 0.3185227	total: 627ms	remaining: 590ms
# 515:	learn: 0.3183539	total: 628ms	remaining: 589ms
# 516:	learn: 0.3182989	total: 629ms	remaining: 588ms
# 517:	learn: 0.3182305	total: 630ms	remaining: 586ms
# 518:	learn: 0.3180852	total: 631ms	remaining: 585ms
# 519:	learn: 0.3178787	total: 632ms	remaining: 584ms
# 520:	learn: 0.3178418	total: 633ms	remaining: 582ms
# 521:	learn: 0.3177847	total: 634ms	remaining: 581ms
# 522:	learn: 0.3176346	total: 636ms	remaining: 580ms
# 523:	learn: 0.3174837	total: 637ms	remaining: 578ms
# 524:	learn: 0.3174777	total: 638ms	remaining: 577ms
# 525:	learn: 0.3172988	total: 639ms	remaining: 576ms
# 526:	learn: 0.3171956	total: 640ms	remaining: 575ms
# 527:	learn: 0.3171362	total: 641ms	remaining: 573ms
# 528:	learn: 0.3170708	total: 642ms	remaining: 572ms
# 529:	learn: 0.3169157	total: 643ms	remaining: 571ms
# 530:	learn: 0.3168203	total: 645ms	remaining: 569ms
# 531:	learn: 0.3168159	total: 646ms	remaining: 568ms
# 532:	learn: 0.3166810	total: 647ms	remaining: 567ms
# 533:	learn: 0.3164211	total: 648ms	remaining: 565ms
# 534:	learn: 0.3164004	total: 649ms	remaining: 564ms
# 535:	learn: 0.3162554	total: 650ms	remaining: 563ms
# 536:	learn: 0.3160762	total: 651ms	remaining: 561ms
# 537:	learn: 0.3159590	total: 652ms	remaining: 560ms
# 538:	learn: 0.3158985	total: 653ms	remaining: 559ms
# 539:	learn: 0.3157870	total: 654ms	remaining: 558ms
# 540:	learn: 0.3157600	total: 656ms	remaining: 556ms
# 541:	learn: 0.3155860	total: 657ms	remaining: 555ms
# 542:	learn: 0.3154545	total: 658ms	remaining: 554ms
# 543:	learn: 0.3153136	total: 659ms	remaining: 552ms
# 544:	learn: 0.3152591	total: 660ms	remaining: 551ms
# 545:	learn: 0.3152141	total: 661ms	remaining: 550ms
# 546:	learn: 0.3150532	total: 662ms	remaining: 549ms
# 547:	learn: 0.3148716	total: 663ms	remaining: 547ms
# 548:	learn: 0.3148002	total: 665ms	remaining: 546ms
# 549:	learn: 0.3146974	total: 666ms	remaining: 545ms
# 550:	learn: 0.3145773	total: 667ms	remaining: 543ms
# 551:	learn: 0.3144219	total: 668ms	remaining: 542ms
# 552:	learn: 0.3143590	total: 669ms	remaining: 541ms
# 553:	learn: 0.3143553	total: 670ms	remaining: 539ms
# 554:	learn: 0.3142573	total: 671ms	remaining: 538ms
# 555:	learn: 0.3141317	total: 672ms	remaining: 537ms
# 556:	learn: 0.3139763	total: 673ms	remaining: 536ms
# 557:	learn: 0.3139079	total: 675ms	remaining: 534ms
# 558:	learn: 0.3139040	total: 676ms	remaining: 533ms
# 559:	learn: 0.3138254	total: 677ms	remaining: 532ms
# 560:	learn: 0.3137472	total: 678ms	remaining: 530ms
# 561:	learn: 0.3136542	total: 679ms	remaining: 529ms
# 562:	learn: 0.3135870	total: 680ms	remaining: 528ms
# 563:	learn: 0.3134621	total: 681ms	remaining: 526ms
# 564:	learn: 0.3133272	total: 682ms	remaining: 525ms
# 565:	learn: 0.3132960	total: 683ms	remaining: 524ms
# 566:	learn: 0.3132651	total: 684ms	remaining: 523ms
# 567:	learn: 0.3131581	total: 686ms	remaining: 521ms
# 568:	learn: 0.3129880	total: 687ms	remaining: 520ms
# 569:	learn: 0.3129553	total: 688ms	remaining: 519ms
# 570:	learn: 0.3128610	total: 689ms	remaining: 518ms
# 571:	learn: 0.3127009	total: 690ms	remaining: 516ms
# 572:	learn: 0.3125703	total: 691ms	remaining: 515ms
# 573:	learn: 0.3123515	total: 692ms	remaining: 514ms
# 574:	learn: 0.3122781	total: 693ms	remaining: 512ms
# 575:	learn: 0.3121553	total: 694ms	remaining: 511ms
# 576:	learn: 0.3120262	total: 695ms	remaining: 510ms
# 577:	learn: 0.3119050	total: 696ms	remaining: 508ms
# 578:	learn: 0.3117881	total: 698ms	remaining: 507ms
# 579:	learn: 0.3115876	total: 699ms	remaining: 506ms
# 580:	learn: 0.3115322	total: 700ms	remaining: 505ms
# 581:	learn: 0.3114766	total: 701ms	remaining: 504ms
# 582:	learn: 0.3113154	total: 703ms	remaining: 503ms
# 583:	learn: 0.3112440	total: 704ms	remaining: 501ms
# 584:	learn: 0.3111490	total: 705ms	remaining: 500ms
# 585:	learn: 0.3109651	total: 706ms	remaining: 499ms
# 586:	learn: 0.3109059	total: 707ms	remaining: 498ms
# 587:	learn: 0.3108674	total: 708ms	remaining: 496ms
# 588:	learn: 0.3107953	total: 710ms	remaining: 495ms
# 589:	learn: 0.3107231	total: 711ms	remaining: 494ms
# 590:	learn: 0.3106416	total: 712ms	remaining: 493ms
# 591:	learn: 0.3105551	total: 713ms	remaining: 491ms
# 592:	learn: 0.3104742	total: 714ms	remaining: 490ms
# 593:	learn: 0.3103645	total: 715ms	remaining: 489ms
# 594:	learn: 0.3102620	total: 716ms	remaining: 487ms
# 595:	learn: 0.3102048	total: 717ms	remaining: 486ms
# 596:	learn: 0.3101378	total: 718ms	remaining: 485ms
# 597:	learn: 0.3100909	total: 720ms	remaining: 484ms
# 598:	learn: 0.3100083	total: 721ms	remaining: 482ms
# 599:	learn: 0.3098864	total: 722ms	remaining: 481ms
# 600:	learn: 0.3097918	total: 723ms	remaining: 480ms
# 601:	learn: 0.3097127	total: 724ms	remaining: 479ms
# 602:	learn: 0.3095734	total: 725ms	remaining: 477ms
# 603:	learn: 0.3094911	total: 726ms	remaining: 476ms
# 604:	learn: 0.3094146	total: 727ms	remaining: 475ms
# 605:	learn: 0.3091785	total: 728ms	remaining: 473ms
# 606:	learn: 0.3090188	total: 729ms	remaining: 472ms
# 607:	learn: 0.3088558	total: 730ms	remaining: 471ms
# 608:	learn: 0.3087928	total: 731ms	remaining: 470ms
# 609:	learn: 0.3087370	total: 733ms	remaining: 468ms
# 610:	learn: 0.3086766	total: 734ms	remaining: 467ms
# 611:	learn: 0.3085612	total: 735ms	remaining: 466ms
# 612:	learn: 0.3083788	total: 736ms	remaining: 465ms
# 613:	learn: 0.3083274	total: 737ms	remaining: 463ms
# 614:	learn: 0.3081971	total: 738ms	remaining: 462ms
# 615:	learn: 0.3080681	total: 739ms	remaining: 461ms
# 616:	learn: 0.3079957	total: 740ms	remaining: 460ms
# 617:	learn: 0.3078613	total: 741ms	remaining: 458ms
# 618:	learn: 0.3077168	total: 742ms	remaining: 457ms
# 619:	learn: 0.3075954	total: 744ms	remaining: 456ms
# 620:	learn: 0.3075773	total: 745ms	remaining: 454ms
# 621:	learn: 0.3074663	total: 746ms	remaining: 453ms
# 622:	learn: 0.3074508	total: 747ms	remaining: 452ms
# 623:	learn: 0.3073810	total: 748ms	remaining: 451ms
# 624:	learn: 0.3072948	total: 749ms	remaining: 450ms
# 625:	learn: 0.3071416	total: 750ms	remaining: 448ms
# 626:	learn: 0.3070088	total: 751ms	remaining: 447ms
# 627:	learn: 0.3068756	total: 752ms	remaining: 446ms
# 628:	learn: 0.3067747	total: 753ms	remaining: 444ms
# 629:	learn: 0.3065836	total: 755ms	remaining: 443ms
# 630:	learn: 0.3064695	total: 756ms	remaining: 442ms
# 631:	learn: 0.3064159	total: 757ms	remaining: 441ms
# 632:	learn: 0.3063747	total: 758ms	remaining: 439ms
# 633:	learn: 0.3063002	total: 759ms	remaining: 438ms
# 634:	learn: 0.3062937	total: 760ms	remaining: 437ms
# 635:	learn: 0.3061617	total: 761ms	remaining: 436ms
# 636:	learn: 0.3060980	total: 763ms	remaining: 435ms
# 637:	learn: 0.3059823	total: 764ms	remaining: 433ms
# 638:	learn: 0.3058710	total: 765ms	remaining: 432ms
# 639:	learn: 0.3058020	total: 766ms	remaining: 431ms
# 640:	learn: 0.3055819	total: 767ms	remaining: 430ms
# 641:	learn: 0.3055054	total: 768ms	remaining: 428ms
# 642:	learn: 0.3054298	total: 769ms	remaining: 427ms
# 643:	learn: 0.3053251	total: 770ms	remaining: 426ms
# 644:	learn: 0.3052398	total: 771ms	remaining: 425ms
# 645:	learn: 0.3051776	total: 773ms	remaining: 423ms
# 646:	learn: 0.3050561	total: 774ms	remaining: 422ms
# 647:	learn: 0.3050064	total: 775ms	remaining: 421ms
# 648:	learn: 0.3049124	total: 777ms	remaining: 420ms
# 649:	learn: 0.3047471	total: 778ms	remaining: 419ms
# 650:	learn: 0.3045530	total: 779ms	remaining: 418ms
# 651:	learn: 0.3045241	total: 780ms	remaining: 416ms
# 652:	learn: 0.3044856	total: 781ms	remaining: 415ms
# 653:	learn: 0.3044063	total: 782ms	remaining: 414ms
# 654:	learn: 0.3042464	total: 784ms	remaining: 413ms
# 655:	learn: 0.3041606	total: 785ms	remaining: 412ms
# 656:	learn: 0.3040768	total: 786ms	remaining: 410ms
# 657:	learn: 0.3039521	total: 787ms	remaining: 409ms
# 658:	learn: 0.3038020	total: 788ms	remaining: 408ms
# 659:	learn: 0.3036818	total: 790ms	remaining: 407ms
# 660:	learn: 0.3035579	total: 791ms	remaining: 406ms
# 661:	learn: 0.3033788	total: 792ms	remaining: 405ms
# 662:	learn: 0.3032838	total: 794ms	remaining: 403ms
# 663:	learn: 0.3031507	total: 795ms	remaining: 402ms
# 664:	learn: 0.3030422	total: 796ms	remaining: 401ms
# 665:	learn: 0.3029375	total: 797ms	remaining: 400ms
# 666:	learn: 0.3028955	total: 799ms	remaining: 399ms
# 667:	learn: 0.3027985	total: 800ms	remaining: 398ms
# 668:	learn: 0.3026509	total: 801ms	remaining: 396ms
# 669:	learn: 0.3025649	total: 802ms	remaining: 395ms
# 670:	learn: 0.3025146	total: 804ms	remaining: 394ms
# 671:	learn: 0.3023390	total: 805ms	remaining: 393ms
# 672:	learn: 0.3022651	total: 806ms	remaining: 392ms
# 673:	learn: 0.3021622	total: 807ms	remaining: 390ms
# 674:	learn: 0.3020451	total: 808ms	remaining: 389ms
# 675:	learn: 0.3019883	total: 810ms	remaining: 388ms
# 676:	learn: 0.3019405	total: 811ms	remaining: 387ms
# 677:	learn: 0.3018339	total: 812ms	remaining: 386ms
# 678:	learn: 0.3017783	total: 813ms	remaining: 385ms
# 679:	learn: 0.3016267	total: 815ms	remaining: 383ms
# 680:	learn: 0.3013942	total: 816ms	remaining: 382ms
# 681:	learn: 0.3012853	total: 817ms	remaining: 381ms
# 682:	learn: 0.3012007	total: 818ms	remaining: 380ms
# 683:	learn: 0.3011705	total: 819ms	remaining: 378ms
# 684:	learn: 0.3011096	total: 821ms	remaining: 377ms
# 685:	learn: 0.3009348	total: 822ms	remaining: 376ms
# 686:	learn: 0.3008449	total: 823ms	remaining: 375ms
# 687:	learn: 0.3007902	total: 824ms	remaining: 374ms
# 688:	learn: 0.3006080	total: 826ms	remaining: 373ms
# 689:	learn: 0.3005506	total: 827ms	remaining: 371ms
# 690:	learn: 0.3004834	total: 828ms	remaining: 370ms
# 691:	learn: 0.3004043	total: 829ms	remaining: 369ms
# 692:	learn: 0.3003711	total: 830ms	remaining: 368ms
# 693:	learn: 0.3002526	total: 831ms	remaining: 367ms
# 694:	learn: 0.3001110	total: 833ms	remaining: 365ms
# 695:	learn: 0.2999675	total: 834ms	remaining: 364ms
# 696:	learn: 0.2999065	total: 835ms	remaining: 363ms
# 697:	learn: 0.2998370	total: 836ms	remaining: 362ms
# 698:	learn: 0.2998258	total: 837ms	remaining: 360ms
# 699:	learn: 0.2997667	total: 838ms	remaining: 359ms
# 700:	learn: 0.2996349	total: 839ms	remaining: 358ms
# 701:	learn: 0.2994951	total: 841ms	remaining: 357ms
# 702:	learn: 0.2994583	total: 842ms	remaining: 356ms
# 703:	learn: 0.2993644	total: 843ms	remaining: 355ms
# 704:	learn: 0.2992827	total: 844ms	remaining: 353ms
# 705:	learn: 0.2991622	total: 845ms	remaining: 352ms
# 706:	learn: 0.2991016	total: 847ms	remaining: 351ms
# 707:	learn: 0.2990365	total: 848ms	remaining: 350ms
# 708:	learn: 0.2990080	total: 849ms	remaining: 348ms
# 709:	learn: 0.2989168	total: 850ms	remaining: 347ms
# 710:	learn: 0.2987435	total: 851ms	remaining: 346ms
# 711:	learn: 0.2986619	total: 853ms	remaining: 345ms
# 712:	learn: 0.2986320	total: 854ms	remaining: 344ms
# 713:	learn: 0.2985341	total: 855ms	remaining: 342ms
# 714:	learn: 0.2984873	total: 856ms	remaining: 341ms
# 715:	learn: 0.2984857	total: 858ms	remaining: 340ms
# 716:	learn: 0.2982706	total: 859ms	remaining: 339ms
# 717:	learn: 0.2981652	total: 860ms	remaining: 338ms
# 718:	learn: 0.2981069	total: 861ms	remaining: 337ms
# 719:	learn: 0.2980266	total: 862ms	remaining: 335ms
# 720:	learn: 0.2979572	total: 864ms	remaining: 334ms
# 721:	learn: 0.2978004	total: 865ms	remaining: 333ms
# 722:	learn: 0.2977045	total: 866ms	remaining: 332ms
# 723:	learn: 0.2976434	total: 867ms	remaining: 331ms
# 724:	learn: 0.2976168	total: 868ms	remaining: 329ms
# 725:	learn: 0.2975025	total: 869ms	remaining: 328ms
# 726:	learn: 0.2973967	total: 871ms	remaining: 327ms
# 727:	learn: 0.2973116	total: 872ms	remaining: 326ms
# 728:	learn: 0.2972244	total: 873ms	remaining: 325ms
# 729:	learn: 0.2971457	total: 874ms	remaining: 323ms
# 730:	learn: 0.2970533	total: 875ms	remaining: 322ms
# 731:	learn: 0.2969893	total: 877ms	remaining: 321ms
# 732:	learn: 0.2967798	total: 878ms	remaining: 320ms
# 733:	learn: 0.2967566	total: 879ms	remaining: 319ms
# 734:	learn: 0.2966702	total: 880ms	remaining: 317ms
# 735:	learn: 0.2966174	total: 882ms	remaining: 316ms
# 736:	learn: 0.2965338	total: 883ms	remaining: 315ms
# 737:	learn: 0.2964939	total: 884ms	remaining: 314ms
# 738:	learn: 0.2963043	total: 885ms	remaining: 313ms
# 739:	learn: 0.2961022	total: 886ms	remaining: 311ms
# 740:	learn: 0.2960656	total: 888ms	remaining: 310ms
# 741:	learn: 0.2960428	total: 889ms	remaining: 309ms
# 742:	learn: 0.2959687	total: 891ms	remaining: 308ms
# 743:	learn: 0.2958734	total: 892ms	remaining: 307ms
# 744:	learn: 0.2957490	total: 893ms	remaining: 306ms
# 745:	learn: 0.2955509	total: 894ms	remaining: 304ms
# 746:	learn: 0.2955169	total: 895ms	remaining: 303ms
# 747:	learn: 0.2954178	total: 896ms	remaining: 302ms
# 748:	learn: 0.2953608	total: 897ms	remaining: 301ms
# 749:	learn: 0.2952902	total: 899ms	remaining: 300ms
# 750:	learn: 0.2951277	total: 900ms	remaining: 298ms
# 751:	learn: 0.2949685	total: 901ms	remaining: 297ms
# 752:	learn: 0.2948339	total: 902ms	remaining: 296ms
# 753:	learn: 0.2947805	total: 904ms	remaining: 295ms
# 754:	learn: 0.2946854	total: 905ms	remaining: 294ms
# 755:	learn: 0.2946308	total: 906ms	remaining: 292ms
# 756:	learn: 0.2944511	total: 907ms	remaining: 291ms
# 757:	learn: 0.2944112	total: 909ms	remaining: 290ms
# 758:	learn: 0.2942371	total: 910ms	remaining: 289ms
# 759:	learn: 0.2941677	total: 911ms	remaining: 288ms
# 760:	learn: 0.2940702	total: 912ms	remaining: 286ms
# 761:	learn: 0.2939452	total: 913ms	remaining: 285ms
# 762:	learn: 0.2939006	total: 914ms	remaining: 284ms
# 763:	learn: 0.2938300	total: 916ms	remaining: 283ms
# 764:	learn: 0.2936780	total: 917ms	remaining: 282ms
# 765:	learn: 0.2935728	total: 918ms	remaining: 281ms
# 766:	learn: 0.2934914	total: 920ms	remaining: 279ms
# 767:	learn: 0.2933427	total: 921ms	remaining: 278ms
# 768:	learn: 0.2932413	total: 922ms	remaining: 277ms
# 769:	learn: 0.2931178	total: 924ms	remaining: 276ms
# 770:	learn: 0.2929587	total: 925ms	remaining: 275ms
# 771:	learn: 0.2928514	total: 926ms	remaining: 273ms
# 772:	learn: 0.2927061	total: 927ms	remaining: 272ms
# 773:	learn: 0.2925812	total: 928ms	remaining: 271ms
# 774:	learn: 0.2924589	total: 929ms	remaining: 270ms
# 775:	learn: 0.2922594	total: 931ms	remaining: 269ms
# 776:	learn: 0.2920851	total: 932ms	remaining: 267ms
# 777:	learn: 0.2920478	total: 933ms	remaining: 266ms
# 778:	learn: 0.2920140	total: 935ms	remaining: 265ms
# 779:	learn: 0.2919744	total: 936ms	remaining: 264ms
# 780:	learn: 0.2918945	total: 937ms	remaining: 263ms
# 781:	learn: 0.2917422	total: 938ms	remaining: 262ms
# 782:	learn: 0.2916372	total: 940ms	remaining: 260ms
# 783:	learn: 0.2915437	total: 941ms	remaining: 259ms
# 784:	learn: 0.2914507	total: 942ms	remaining: 258ms
# 785:	learn: 0.2913415	total: 943ms	remaining: 257ms
# 786:	learn: 0.2911029	total: 944ms	remaining: 256ms
# 787:	learn: 0.2910754	total: 946ms	remaining: 254ms
# 788:	learn: 0.2909523	total: 947ms	remaining: 253ms
# 789:	learn: 0.2909156	total: 948ms	remaining: 252ms
# 790:	learn: 0.2908364	total: 949ms	remaining: 251ms
# 791:	learn: 0.2908070	total: 951ms	remaining: 250ms
# 792:	learn: 0.2907496	total: 952ms	remaining: 248ms
# 793:	learn: 0.2906555	total: 953ms	remaining: 247ms
# 794:	learn: 0.2905736	total: 954ms	remaining: 246ms
# 795:	learn: 0.2904854	total: 955ms	remaining: 245ms
# 796:	learn: 0.2903578	total: 957ms	remaining: 244ms
# 797:	learn: 0.2902197	total: 958ms	remaining: 242ms
# 798:	learn: 0.2901662	total: 959ms	remaining: 241ms
# 799:	learn: 0.2900105	total: 960ms	remaining: 240ms
# 800:	learn: 0.2899573	total: 961ms	remaining: 239ms
# 801:	learn: 0.2898600	total: 963ms	remaining: 238ms
# 802:	learn: 0.2897449	total: 964ms	remaining: 236ms
# 803:	learn: 0.2896495	total: 965ms	remaining: 235ms
# 804:	learn: 0.2895920	total: 966ms	remaining: 234ms
# 805:	learn: 0.2893745	total: 968ms	remaining: 233ms
# 806:	learn: 0.2892993	total: 969ms	remaining: 232ms
# 807:	learn: 0.2891257	total: 970ms	remaining: 230ms
# 808:	learn: 0.2890791	total: 971ms	remaining: 229ms
# 809:	learn: 0.2890128	total: 972ms	remaining: 228ms
# 810:	learn: 0.2889883	total: 973ms	remaining: 227ms
# 811:	learn: 0.2889388	total: 974ms	remaining: 226ms
# 812:	learn: 0.2888491	total: 975ms	remaining: 224ms
# 813:	learn: 0.2888021	total: 977ms	remaining: 223ms
# 814:	learn: 0.2886837	total: 978ms	remaining: 222ms
# 815:	learn: 0.2886261	total: 979ms	remaining: 221ms
# 816:	learn: 0.2884976	total: 981ms	remaining: 220ms
# 817:	learn: 0.2883197	total: 982ms	remaining: 219ms
# 818:	learn: 0.2882823	total: 983ms	remaining: 217ms
# 819:	learn: 0.2881921	total: 984ms	remaining: 216ms
# 820:	learn: 0.2880640	total: 986ms	remaining: 215ms
# 821:	learn: 0.2878712	total: 987ms	remaining: 214ms
# 822:	learn: 0.2877754	total: 988ms	remaining: 212ms
# 823:	learn: 0.2877437	total: 989ms	remaining: 211ms
# 824:	learn: 0.2876630	total: 990ms	remaining: 210ms
# 825:	learn: 0.2874961	total: 991ms	remaining: 209ms
# 826:	learn: 0.2874551	total: 992ms	remaining: 208ms
# 827:	learn: 0.2873539	total: 993ms	remaining: 206ms
# 828:	learn: 0.2872642	total: 995ms	remaining: 205ms
# 829:	learn: 0.2871784	total: 996ms	remaining: 204ms
# 830:	learn: 0.2871390	total: 997ms	remaining: 203ms
# 831:	learn: 0.2870389	total: 999ms	remaining: 202ms
# 832:	learn: 0.2869655	total: 1000ms	remaining: 200ms
# 833:	learn: 0.2868478	total: 1s	remaining: 199ms
# 834:	learn: 0.2867289	total: 1s	remaining: 198ms
# 835:	learn: 0.2866571	total: 1s	remaining: 197ms
# 836:	learn: 0.2866405	total: 1s	remaining: 196ms
# 837:	learn: 0.2865789	total: 1s	remaining: 194ms
# 838:	learn: 0.2864875	total: 1.01s	remaining: 193ms
# 839:	learn: 0.2863274	total: 1.01s	remaining: 192ms
# 840:	learn: 0.2862879	total: 1.01s	remaining: 191ms
# 841:	learn: 0.2862192	total: 1.01s	remaining: 190ms
# 842:	learn: 0.2861160	total: 1.01s	remaining: 188ms
# 843:	learn: 0.2859844	total: 1.01s	remaining: 187ms
# 844:	learn: 0.2857399	total: 1.01s	remaining: 186ms
# 845:	learn: 0.2856407	total: 1.01s	remaining: 185ms
# 846:	learn: 0.2854693	total: 1.02s	remaining: 184ms
# 847:	learn: 0.2853918	total: 1.02s	remaining: 182ms
# 848:	learn: 0.2853909	total: 1.02s	remaining: 181ms
# 849:	learn: 0.2852121	total: 1.02s	remaining: 180ms
# 850:	learn: 0.2851710	total: 1.02s	remaining: 179ms
# 851:	learn: 0.2851128	total: 1.02s	remaining: 178ms
# 852:	learn: 0.2849801	total: 1.02s	remaining: 176ms
# 853:	learn: 0.2848730	total: 1.02s	remaining: 175ms
# 854:	learn: 0.2847718	total: 1.02s	remaining: 174ms
# 855:	learn: 0.2846396	total: 1.03s	remaining: 173ms
# 856:	learn: 0.2845481	total: 1.03s	remaining: 172ms
# 857:	learn: 0.2845096	total: 1.03s	remaining: 170ms
# 858:	learn: 0.2844633	total: 1.03s	remaining: 169ms
# 859:	learn: 0.2843473	total: 1.03s	remaining: 168ms
# 860:	learn: 0.2841694	total: 1.03s	remaining: 167ms
# 861:	learn: 0.2841321	total: 1.03s	remaining: 165ms
# 862:	learn: 0.2840891	total: 1.03s	remaining: 164ms
# 863:	learn: 0.2839640	total: 1.03s	remaining: 163ms
# 864:	learn: 0.2838712	total: 1.04s	remaining: 162ms
# 865:	learn: 0.2838028	total: 1.04s	remaining: 161ms
# 866:	learn: 0.2836863	total: 1.04s	remaining: 159ms
# 867:	learn: 0.2836131	total: 1.04s	remaining: 158ms
# 868:	learn: 0.2836005	total: 1.04s	remaining: 157ms
# 869:	learn: 0.2835062	total: 1.04s	remaining: 156ms
# 870:	learn: 0.2833882	total: 1.04s	remaining: 155ms
# 871:	learn: 0.2833095	total: 1.04s	remaining: 153ms
# 872:	learn: 0.2832515	total: 1.05s	remaining: 152ms
# 873:	learn: 0.2831753	total: 1.05s	remaining: 151ms
# 874:	learn: 0.2830926	total: 1.05s	remaining: 150ms
# 875:	learn: 0.2829101	total: 1.05s	remaining: 149ms
# 876:	learn: 0.2828106	total: 1.05s	remaining: 147ms
# 877:	learn: 0.2827144	total: 1.05s	remaining: 146ms
# 878:	learn: 0.2825898	total: 1.05s	remaining: 145ms
# 879:	learn: 0.2825273	total: 1.05s	remaining: 144ms
# 880:	learn: 0.2825000	total: 1.05s	remaining: 143ms
# 881:	learn: 0.2823815	total: 1.06s	remaining: 141ms
# 882:	learn: 0.2822760	total: 1.06s	remaining: 140ms
# 883:	learn: 0.2822260	total: 1.06s	remaining: 139ms
# 884:	learn: 0.2821683	total: 1.06s	remaining: 138ms
# 885:	learn: 0.2820351	total: 1.06s	remaining: 137ms
# 886:	learn: 0.2819265	total: 1.06s	remaining: 135ms
# 887:	learn: 0.2818831	total: 1.06s	remaining: 134ms
# 888:	learn: 0.2818173	total: 1.06s	remaining: 133ms
# 889:	learn: 0.2817173	total: 1.06s	remaining: 132ms
# 890:	learn: 0.2816700	total: 1.07s	remaining: 131ms
# 891:	learn: 0.2816458	total: 1.07s	remaining: 129ms
# 892:	learn: 0.2815664	total: 1.07s	remaining: 128ms
# 893:	learn: 0.2814772	total: 1.07s	remaining: 127ms
# 894:	learn: 0.2814434	total: 1.07s	remaining: 126ms
# 895:	learn: 0.2813955	total: 1.07s	remaining: 125ms
# 896:	learn: 0.2812253	total: 1.07s	remaining: 123ms
# 897:	learn: 0.2811607	total: 1.07s	remaining: 122ms
# 898:	learn: 0.2810257	total: 1.08s	remaining: 121ms
# 899:	learn: 0.2809226	total: 1.08s	remaining: 120ms
# 900:	learn: 0.2808890	total: 1.08s	remaining: 119ms
# 901:	learn: 0.2807922	total: 1.08s	remaining: 117ms
# 902:	learn: 0.2807400	total: 1.08s	remaining: 116ms
# 903:	learn: 0.2806140	total: 1.08s	remaining: 115ms
# 904:	learn: 0.2805711	total: 1.08s	remaining: 114ms
# 905:	learn: 0.2805396	total: 1.08s	remaining: 113ms
# 906:	learn: 0.2803928	total: 1.09s	remaining: 111ms
# 907:	learn: 0.2802530	total: 1.09s	remaining: 110ms
# 908:	learn: 0.2802371	total: 1.09s	remaining: 109ms
# 909:	learn: 0.2801524	total: 1.09s	remaining: 108ms
# 910:	learn: 0.2800262	total: 1.09s	remaining: 107ms
# 911:	learn: 0.2799517	total: 1.09s	remaining: 105ms
# 912:	learn: 0.2799263	total: 1.09s	remaining: 104ms
# 913:	learn: 0.2798519	total: 1.09s	remaining: 103ms
# 914:	learn: 0.2798154	total: 1.09s	remaining: 102ms
# 915:	learn: 0.2796592	total: 1.1s	remaining: 101ms
# 916:	learn: 0.2795612	total: 1.1s	remaining: 99.4ms
# 917:	learn: 0.2795259	total: 1.1s	remaining: 98.2ms
# 918:	learn: 0.2794768	total: 1.1s	remaining: 97ms
# 919:	learn: 0.2794154	total: 1.1s	remaining: 95.8ms
# 920:	learn: 0.2793944	total: 1.1s	remaining: 94.6ms
# 921:	learn: 0.2793306	total: 1.1s	remaining: 93.4ms
# 922:	learn: 0.2792844	total: 1.1s	remaining: 92.2ms
# 923:	learn: 0.2791883	total: 1.11s	remaining: 91ms
# 924:	learn: 0.2790419	total: 1.11s	remaining: 89.8ms
# 925:	learn: 0.2789395	total: 1.11s	remaining: 88.6ms
# 926:	learn: 0.2789171	total: 1.11s	remaining: 87.4ms
# 927:	learn: 0.2788975	total: 1.11s	remaining: 86.2ms
# 928:	learn: 0.2788125	total: 1.11s	remaining: 85ms
# 929:	learn: 0.2787686	total: 1.11s	remaining: 83.8ms
# 930:	learn: 0.2786704	total: 1.11s	remaining: 82.6ms
# 931:	learn: 0.2786291	total: 1.11s	remaining: 81.4ms
# 932:	learn: 0.2785390	total: 1.12s	remaining: 80.2ms
# 933:	learn: 0.2785296	total: 1.12s	remaining: 79ms
# 934:	learn: 0.2784531	total: 1.12s	remaining: 77.8ms
# 935:	learn: 0.2784205	total: 1.12s	remaining: 76.6ms
# 936:	learn: 0.2783938	total: 1.12s	remaining: 75.4ms
# 937:	learn: 0.2783715	total: 1.12s	remaining: 74.2ms
# 938:	learn: 0.2782537	total: 1.12s	remaining: 73ms
# 939:	learn: 0.2781291	total: 1.12s	remaining: 71.8ms
# 940:	learn: 0.2779819	total: 1.13s	remaining: 70.6ms
# 941:	learn: 0.2779045	total: 1.13s	remaining: 69.4ms
# 942:	learn: 0.2778524	total: 1.13s	remaining: 68.2ms
# 943:	learn: 0.2778153	total: 1.13s	remaining: 67ms
# 944:	learn: 0.2777542	total: 1.13s	remaining: 65.8ms
# 945:	learn: 0.2777195	total: 1.13s	remaining: 64.6ms
# 946:	learn: 0.2776658	total: 1.13s	remaining: 63.4ms
# 947:	learn: 0.2774943	total: 1.13s	remaining: 62.2ms
# 948:	learn: 0.2774681	total: 1.14s	remaining: 61ms
# 949:	learn: 0.2773067	total: 1.14s	remaining: 59.8ms
# 950:	learn: 0.2772024	total: 1.14s	remaining: 58.6ms
# 951:	learn: 0.2771054	total: 1.14s	remaining: 57.4ms
# 952:	learn: 0.2770165	total: 1.14s	remaining: 56.2ms
# 953:	learn: 0.2769621	total: 1.15s	remaining: 55.4ms
# 954:	learn: 0.2768393	total: 1.15s	remaining: 54.2ms
# 955:	learn: 0.2767782	total: 1.15s	remaining: 53ms
# 956:	learn: 0.2767479	total: 1.15s	remaining: 51.8ms
# 957:	learn: 0.2766504	total: 1.15s	remaining: 50.6ms
# 958:	learn: 0.2765954	total: 1.16s	remaining: 49.4ms
# 959:	learn: 0.2765411	total: 1.16s	remaining: 48.2ms
# 960:	learn: 0.2764274	total: 1.16s	remaining: 47ms
# 961:	learn: 0.2763366	total: 1.16s	remaining: 45.8ms
# 962:	learn: 0.2763035	total: 1.16s	remaining: 44.6ms
# 963:	learn: 0.2762462	total: 1.16s	remaining: 43.4ms
# 964:	learn: 0.2762316	total: 1.16s	remaining: 42.2ms
# 965:	learn: 0.2761737	total: 1.16s	remaining: 41ms
# 966:	learn: 0.2761354	total: 1.16s	remaining: 39.8ms
# 967:	learn: 0.2760119	total: 1.17s	remaining: 38.6ms
# 968:	learn: 0.2759184	total: 1.17s	remaining: 37.3ms
# 969:	learn: 0.2758910	total: 1.17s	remaining: 36.1ms
# 970:	learn: 0.2757891	total: 1.17s	remaining: 34.9ms
# 971:	learn: 0.2757368	total: 1.17s	remaining: 33.7ms
# 972:	learn: 0.2756603	total: 1.17s	remaining: 32.5ms
# 973:	learn: 0.2755084	total: 1.17s	remaining: 31.3ms
# 974:	learn: 0.2754036	total: 1.17s	remaining: 30.1ms
# 975:	learn: 0.2753493	total: 1.18s	remaining: 28.9ms
# 976:	learn: 0.2752905	total: 1.18s	remaining: 27.7ms
# 977:	learn: 0.2752612	total: 1.18s	remaining: 26.5ms
# 978:	learn: 0.2751692	total: 1.18s	remaining: 25.3ms
# 979:	learn: 0.2750651	total: 1.18s	remaining: 24.1ms
# 980:	learn: 0.2750358	total: 1.18s	remaining: 22.9ms
# 981:	learn: 0.2749383	total: 1.18s	remaining: 21.7ms
# 982:	learn: 0.2748849	total: 1.18s	remaining: 20.5ms
# 983:	learn: 0.2748560	total: 1.19s	remaining: 19.3ms
# 984:	learn: 0.2747947	total: 1.19s	remaining: 18.1ms
# 985:	learn: 0.2747596	total: 1.19s	remaining: 16.9ms
# 986:	learn: 0.2746918	total: 1.19s	remaining: 15.7ms
# 987:	learn: 0.2745796	total: 1.19s	remaining: 14.5ms
# 988:	learn: 0.2745549	total: 1.19s	remaining: 13.3ms
# 989:	learn: 0.2744650	total: 1.19s	remaining: 12ms
# 990:	learn: 0.2743232	total: 1.19s	remaining: 10.8ms
# 991:	learn: 0.2742119	total: 1.19s	remaining: 9.63ms
# 992:	learn: 0.2741830	total: 1.2s	remaining: 8.43ms
# 993:	learn: 0.2740331	total: 1.2s	remaining: 7.22ms
# 994:	learn: 0.2739266	total: 1.2s	remaining: 6.02ms
# 995:	learn: 0.2738892	total: 1.2s	remaining: 4.82ms
# 996:	learn: 0.2737684	total: 1.2s	remaining: 3.61ms
# 997:	learn: 0.2737143	total: 1.2s	remaining: 2.41ms
# 998:	learn: 0.2735943	total: 1.2s	remaining: 1.2ms
# 999:	learn: 0.2735009	total: 1.2s	remaining: 0us

# %% [markdown]
# 2. generate the confusion matrix and calculate the accuracy, precision, recall, and F1-score on training set.

# %%
Y_pred = model.predict(X_train)
# we need to convert the predictions to binary values
Y_predBinary = [1 if x > 0.5 else 0 for x in Y_pred]

cm = confusion_matrix(Y_train, Y_predBinary)
# Optionally, convert the confusion matrix to a DataFrame for better readability
#cm = cm.astype('string')
cm2 = [
    [f"{cm[0][0]} TP", f"{cm[0][1]} FP"],
    [f"{cm[1][0]} FN", f"{cm[1][1]} TN"]
]
cm_df = pd.DataFrame(cm2, index=['Actual Positive', 'Actual Negative'], columns=['Predicted Positive', 'Predicted Negative'])
display(cm_df)

scores = pd.DataFrame([
    accuracy_score(Y_train, Y_predBinary),
    precision_score(Y_train, Y_predBinary),
    recall_score(Y_train, Y_predBinary),
    f1_score(Y_train, Y_predBinary)
]
    , index=['Accuracy', 'Precision', 'Recall', 'F1'], columns=['Score (train)'])
display(scores)
# Out:
#                 Predicted Positive Predicted Negative
# Actual Positive            1529 TP              36 FP
# Actual Negative             159 FN             376 TN
#            Score (train)
# Accuracy        0.907143
# Precision       0.912621
# Recall          0.702804
# F1              0.794087

# %% [markdown]
# 3. Applying the model in the test set and generating the prediction

# %%
X_test = testDataDummies.drop(columns=['target'])
Y_test = testDataDummies['target']

Y_pred_test = model.predict(X_test)

# %% [markdown]
# 4. generate the confusion matrix from the test set and calculate the accuracy, precision, recall, and F1-score

# %%
Y_pred_test = model.predict(X_test)
# we need to convert the predictions to binary values
Y_pred_testBinary = [1 if x > 0.5 else 0 for x in Y_pred_test]

cm = confusion_matrix(Y_test, Y_pred_testBinary)
# Optionally, convert the confusion matrix to a DataFrame for better readability
#cm = cm.astype('string')
cm2 = [
    [f"{cm[0][0]} TP", f"{cm[0][1]} FP"],
    [f"{cm[1][0]} FN", f"{cm[1][1]} TN"]
]
display(pd.DataFrame(cm2, index=['Actual Positive', 'Actual Negative'], columns=['Predicted Positive', 'Predicted Negative']))

display(pd.DataFrame([
    accuracy_score(Y_test, Y_pred_testBinary),
    precision_score(Y_test, Y_pred_testBinary),
    recall_score(Y_test, Y_pred_testBinary),
    f1_score(Y_test, Y_pred_testBinary)
]
    , index=['Accuracy', 'Precision', 'Recall', 'F1'], columns=['Score (test)']))
# Out:
#                 Predicted Positive Predicted Negative
# Actual Positive              70 TP               8 FP
# Actual Negative              16 FN               6 TN
#            Score (test)
# Accuracy       0.760000
# Precision      0.428571
# Recall         0.272727
# F1             0.333333

# %% [markdown]
# 5. compare the results between the training and test set
# It appears the model is working much worse on the test data than on the training data - all the scores are much lower, with precision going down from over 90% to just 42%. this might be due to a bad selection of the test data, or because something with the columns having to be mapped to bools might overextend a certain value's importance.
#
# Maybe i picked a bad algorithm with CatBoost, too, but since you made it our choice, and it was very easy to find a reference to it, i chose that one.

# %% [markdown]
# The data is modifed , but you can get some help from [(https://www.kaggle.com/datasets/arashnic/hr-analytics-job-change-of-data-scientists?select=sample_submission.csv)Kaggle]
#
# ## Extra point
# Think about what kind of the method can increase the performance (does not need to run )

# %% [markdown]
# Maybe using dummy-values (additional bool columns) for nonnumeric fields is bad for performance, when i executed the model, everything was quite fast, so i have no problem.
#
# if the raw data files were any kind of big, the repetition for nonnumeric strings of course is a hindrance and they could be replaced by number-encodings like:
#     no_enrollment=1
#     Part time course=2
#     Full time course=3
# but this might be dangerous, since the person training the model might overlook the fact that those do not represent continuous values and so the model might learn wrong.
#
# of course, choosing a different algorithm is probably significant for the performance, too.
